# %%
#Week 3 Assignment - Sinjini Bose 

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Automobile.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plot a Horizontal line at y = 5
plt.axhline(y=5, color='r', linestyle='--')

# %%
#Increase the thickness of a line with Matplotlib
import numpy as np
import matplotlib.pyplot as plt 
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], linewidth=3)

# %%
#plotting
df = pd.read_csv('Automobile.csv')

df.plot()

plt.show()

# %%
#scatter plot eg1 
df = pd.read_csv('Automobile.csv')
df.plot(kind = 'scatter', x = 'compression-ratio', y = 'stroke')

plt.show()

# %%
#scatterplot with title and increased size
df.plot(kind='scatter', x='compression-ratio', y='stroke', figsize=(8, 10))

plt.title('Compression Ratio vs Stroke')
plt.xlabel('Compression Ratio')
plt.ylabel('Stroke')

plt.show()

# %%
#scatter plot eg2

df = pd.read_csv('Automobile.csv')
df.plot(kind = 'scatter', x = 'compression-ratio', y = 'city-mpg')

plt.show()

# %%
df = pd.read_csv('Automobile.csv')
df.plot(kind = 'scatter', x = 'city-mpg', y = 'highway-mpg')

plt.show()

# %%
#adding labels
df.plot(kind='scatter', x='city-mpg', y = 'highway-mpg', figsize=(6, 5))
plt.title('city-mpg vs highway-mpg')
plt.xlabel('city-mpg')
plt.ylabel('highway-mpg')
plt.show()

# %%
#scatterplot with several colours
city_mpg = df['city-mpg']
highway_mpg = df['highway-mpg']
car_make = df['make']

plt.figure(figsize=(7, 7))

for make, color in colors.items():
    plt.scatter(city_mpg[car_make == make], highway_mpg[car_make == make], color=color, label=make, alpha=0.7)

plt.xlabel('City MPG')
plt.ylabel('Highway MPG')
plt.title('City MPG vs Highway MPG ')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#histogram

df["engine-size"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Plot the histogram with a specific color and labels
plt.figure(figsize=(6, 6))
df['engine-size'].plot(kind='hist', color='purple', edgecolor='black', alpha=0.7)

plt.xlabel('Engine Size')
plt.ylabel('Frequency')
plt.title('Histogram of Engine Size')

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#barchart
makes = df['make']
city_mpg = df['city-mpg']
highway_mpg = df['highway-mpg']


plt.figure(figsize=(5, 5))

# Plotting city MPG bars
city_bars = plt.barh(makes, city_mpg, color='skyblue', label='City MPG')

# Plotting highway MPG bars with proper left alignment
highway_bars = plt.barh(makes, highway_mpg, left=city_mpg, color='lightpink', label='Highway MPG')
